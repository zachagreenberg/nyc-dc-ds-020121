# %% [markdown]
# # Using APIs and JSON Data

# %% [markdown]
# ## Objectives
# You will be able to:
# * Make an API call to Yelp

# %% [markdown]
# ## Agenda
#
# * Build up an API Call
# * Look at the results

# %%
import requests #helps get API call
import json #helps to make the call readable

# %% [markdown]
# For more information about the request package you can use the following resources:
#
# **Tutorial:** https://realpython.com/python-requests/
#
# **Package Documentation:** https://requests.readthedocs.io/en/master/

# %% [markdown]
# ![](quota.png)

# %% [markdown]
# Let's do a search of businesses on the Yelp API.

# %%
import sys
print(sys.path)
# Out:
# ['/Users/zachgreenberg/Documents/Flatiron/nyc-dc-ds-020121/Phase_1/ds-apis_json-main', '/opt/anaconda3/envs/learn-env/lib/python38.zip', '/opt/anaconda3/envs/learn-env/lib/python3.8', '/opt/anaconda3/envs/learn-env/lib/python3.8/lib-dynload', '', '/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages', '/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/IPython/extensions', '/Users/zachgreenberg/.ipython']

# %%
# set theurl and endpoint we want to hit
url =  'https://api.yelp.com/v3/businesses/search'

# %% [markdown]
# Now that you have an API key, let's enter set that information here so that we can do our searches. Once you have the `api_key` variable, place int in our header.

# %%
client_id = #ENTER CLIENT ID
api_key = #ENTER API KEY

# %%
# from  keys  import  client_id, api_key (THIS WOULD BE IN A PRIVATE .PY FILE)

# %%
headers = {
        'Authorization': 'Bearer {}'.format(api_key),
    }

# %% [markdown]
# We now need to determine our parameters we want to pass.
#
# You must give a specific search term, location and one other paramter to limit your search.
#
# Remember you can search the API documenation to find another parameter to limit your search.
# https://www.yelp.com/developers/documentation/v3/get_started

# %% [markdown]
# > ^CLICK ON THE LINK ABOVE AND SEARCH BY PATH FOR A LIST OF PARAMETERS TO PASS

# %%
# what type of business do you want to search
term = 'Thai'

#where do you want to perform this search
location = 'Queens'

# what is your other parameter you want to search against
categories = 'restaurants'

# %%
url_params = {
                "term": term.replace(' ', '+'),
                "location": location.replace(' ', '+'),
                "categories" : categories,
                "limit": 50,
    
            }

# %%
url_params
# Out:
# {'term': 'Thai',
#  'location': 'Queens',
#  'categories': 'restaurants',
#  'limit': 50}

# %% [markdown]
# Now that we have all of the parts necessary for an API call, let's put them together.

# %%
response = requests.get(url, headers=headers, params=url_params)

# %% [markdown]
# >url is called business endpoint
# The request package creates the full url for us with the '?' for params

# %%
url
# Out:
# 'https://api.yelp.com/v3/businesses/search'

# %%
response.status_code
# Out:
# 200

# %% [markdown]
# ## The Response
#
# The response of a GET request often has some valuable information, known as a payload, in the message body. Using the attributes and methods of Response, you can view the payload in a variety of different formats.
#
# To see the response’s content in bytes, you use `.content`
#
# You will often want to convert them into a string using a character encoding such as UTF-8. Response will do that for you when you access `.text`
#
# The response is actually serialized JSON content. To get a dictionary, you could take the str you retrieved from `.text` and deserialize it using `json.loads()`. However, a simpler way to accomplish this task is to use `.json()`:

# %%
response.text
# Out:
# '{"businesses": [{"id": "uazg6WhYVOw3jhWCG_MDBg", "alias": "sup-thai-kitchen-fresh-meadows", "name": "Sup Thai Kitchen", "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/ouTt4JK93LOG0P7fSG1r7g/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/sup-thai-kitchen-fresh-meadows?adjust_creative=BEubh_gw8oLY50Nph3EDhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BEubh_gw8oLY50Nph3EDhg", "review_count": 373, "categories": [{"alias": "thai", "title": "Thai"}, {"alias": "seafood", "title": "Seafood"}, {"alias": "noodles", "title": "Noodles"}], "rating": 4.5, "coordinates": {"latitude": 40.7266838, "longitude": -73.7894371}, "transactions": ["delivery", "pickup"], "price": "$$", "location": {"address1": "178-19 Union Tpke", "address2": null, "address3": "", "city": "Fresh Meadows", "zip_code": "11366", "country": "US", "state": "NY", "display_address": ["178-19 Union Tpke", "Fresh Meadows, NY 11366"]}, "phone": "+17184874449", "display_phone": "(718) 487-4449", "distance": 5378.159709707153}, {"id": "cegA4jf16vEt7NCQ7cpu2w", "alias": "kind-fresh-meadows", "name": "Kin\'d", "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/3rnKMO-RGXBAVYXAgffmwQ/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/kind-fresh-meadows?adjust_creative=BEubh_gw8oLY50Nph3EDhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BEubh_gw8oLY50Nph3EDhg", "review_count": 767, "categories": [{"alias": "thai", "title": "Thai"}], "rating": 4.5, "coordinates": {"latitude": 40.73031, "longitude": -73.77814}, "transactions": ["delivery", "pickup"], "price": "$$", "location": {"address1": "192-03 Union Tpke", "address2": "", "address3": null, "city": "Fresh Meadows", "zip_code": "11366", "country": "US", "state": "NY", "display_address": ["192-03 Union Tpke", "Fresh Meadows, NY 11366"]}, "phone": "+17184680888", "display_phone": "(718) 468-0888", "distance": 6273.193942408963}, {"id": "0L03onqNwxWLrbb_FCK79A", "alias": "sripraphai-thai-restaurant-woodside", "name": "SriPraPhai Thai Restaurant", "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/DBYmdu8aWPzPWKJzvPm-aQ/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/sripraphai-thai-restaurant-woodside?adjust_creative=BEubh_gw8oLY50Nph3EDhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BEubh_gw8oLY50Nph3EDhg", "review_count": 2380, "categories": [{"alias": "thai", "title": "Thai"}], "rating": 4.0, "coordinates": {"latitude": 40.7464987, "longitude": -73.8992328}, "transactions": [], "price": "$$", "location": {"address1": "64-13 39th Ave", "address2": "", "address3": "", "city": "Woodside", "zip_code": "11377", "country": "US", "state": "NY", "display_address": ["64-13 39th Ave", "Woodside, NY 11377"]}, "phone": "+17188999599", "display_phone": "(718) 899-9599", "distance": 4250.747809627073}, {"id": "gr3wUszE1972q0GBkmwEXQ", "alias": "bangkok-cuisine-forest-hills", "name": "Bangkok Cuisine", "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/8vTa_qflOZVu30D0k0HSTg/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/bangkok-cuisine-forest-hills?adjust_creative=BEubh_gw8oLY50Nph3EDhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BEubh_gw8oLY50Nph3EDhg", "review_count": 421, "categories": [{"alias": "thai", "title": "Thai"}], "rating": 4.0, "coordinates": {"latitude": 40.720954, "longitude": -73.845238}, "transactions": ["delivery", "pickup"], "price": "$$", "location": {"address1": "10718 70th Rd", "address2": "", "address3": "", "city": "Forest Hills", "zip_code": "11375", "country": "US", "state": "NY", "display_address": ["10718 70th Rd", "Forest Hills, NY 11375"]}, "phone": "+17182614005", "display_phone": "(718) 261-4005", "distance": 1329.980593467087}, {"id": "jMb34zhfkqoW866F10hf1Q", "alias": "grace-thai-restaurant-elmhurst", "name": "Grace Thai Restaurant", "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/JtXzAAG2jsoperWNGOANSA/o.jpg", "is_closed": false, "url": "htt ...

# %%
json.loads(response.text)
# Out:
# {'businesses': [{'id': 'uazg6WhYVOw3jhWCG_MDBg',
#    'alias': 'sup-thai-kitchen-fresh-meadows',
#    'name': 'Sup Thai Kitchen',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ouTt4JK93LOG0P7fSG1r7g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sup-thai-kitchen-fresh-meadows?adjust_creative=BEubh_gw8oLY50Nph3EDhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BEubh_gw8oLY50Nph3EDhg',
#    'review_count': 373,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7266838, 'longitude': -73.7894371},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '178-19 Union Tpke',
#     'address2': None,
#     'address3': '',
#     'city': 'Fresh Meadows',
#     'zip_code': '11366',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['178-19 Union Tpke', 'Fresh Meadows, NY 11366']},
#    'phone': '+17184874449',
#    'display_phone': '(718) 487-4449',
#    'distance': 5378.159709707153},
#   {'id': 'cegA4jf16vEt7NCQ7cpu2w',
#    'alias': 'kind-fresh-meadows',
#    'name': "Kin'd",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/3rnKMO-RGXBAVYXAgffmwQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kind-fresh-meadows?adjust_creative=BEubh_gw8oLY50Nph3EDhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BEubh_gw8oLY50Nph3EDhg',
#    'review_count': 767,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.73031, 'longitude': -73.77814},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '192-03 Union Tpke',
#     'address2': '',
#     'address3': None,
#     'city': 'Fresh Meadows',
#     'zip_code': '11366',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['192-03 Union Tpke', 'Fresh Meadows, NY 11366']},
#    'phone': '+17184680888',
#    'display_phone': '(718) 468-0888',
#    'distance': 6273.193942408963},
#   {'id': '0L03onqNwxWLrbb_FCK79A',
#    'alias': 'sripraphai-thai-restaurant-woodside',
#    'name': 'SriPraPhai Thai Restaurant',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/DBYmdu8aWPzPWKJzvPm-aQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sripraphai-thai-restaurant-woodside?adjust_creative=BEubh_gw8oLY50Nph3EDhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BEubh_gw8oLY50Nph3EDhg',
#    'review_count': 2380,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7464987, 'longitude': -73.8992328},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '64-13 39th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Woodside',
#     'zip_code': '11377',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['64-13 39th Ave', 'Woodside, NY 11377']},
#    'phone': '+17188999599',
#    'display_phone': '(718) 899-9599',
#    'distance': 4250.747809627073},
#   {'id': 'gr3wUszE1972q0GBkmwEXQ',
#    'alias': 'bangkok-cuisine-forest-hills',
#    'name': 'Bangkok Cuisine',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/8vTa_qflOZVu30D0k0HSTg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bangkok-cuisine-forest-hills?adjust_creative=BEubh_gw8oLY50Nph3EDhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BEubh_gw8oLY50Nph3EDhg',
#    'review_count': 421,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.720954, 'longitude': -73.845238},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '10718 70th Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Forest Hills',
#     'zip_code': '11375',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['10718 70th Rd', 'Forest Hills, NY 11375']},
#    'phone': '+17182614005',
#    'display_phone': '(718) 261-4005',
#    'distance': 1329.980593467087},
#   {'id': 'jMb34zhfkqoW866F10hf1Q',
#    'alias': 'grace-thai-restaurant-elmhurst',
#    'name': 'Grace Thai Restaurant',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/JtXzAAG2jsoperWNGOANSA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/grace-thai-restaurant-elmhurst?adjust_creative=BEubh_gw8oLY50Nph3EDhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BEubh_gw8oLY50Nph3EDhg',
#    'review_count': 52,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.736905, 'longitude': -73.865734},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '5617 Junction Blvd',
#     'address2': None,
#     'address3': '',
#     'city': 'Elmhurst',
#     'zip_code': '11373',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['5617 Junction Blvd', 'Elmhurst, NY 11373']},
#    'phone': '+19294633693',
#    'display_phone': '(929) 463-3693',
#    'distance': 1241.9783887099397},
#   {'id': '3GMHPnrkFAcqffw3T7JSdQ',
#    'alias': 'kitchen-79-jackson-heights',
#    'name': 'Kitchen 79',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ip9F8-pOstZmt7_8T_46Jg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kitchen-79-jackson-heights?adjust_creative=BEubh_gw8oLY50Nph3EDhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BEubh_gw8oLY50Nph3EDhg',
#    'review_count': 629,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.747551, 'longitude': -73.8868866},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '37-70 79th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Jackson Heights',
#     'zip_code': '11372',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['37-70 79th St', 'Jackson Heights, NY 11372']},
#    'phone': '+17188036227',
#    'display_phone': '(718) 803-6227',
#    'distance': 3388.369692606335},
#   {'id': 'fRO4Fwe5uRAajMcTwLbVkA',
#    'alias': 'ayada-thai-elmhurst-2',
#    'name': 'Ayada Thai',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/qybFSiSVmsTTXx5fmX3BNQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ayada-thai-elmhurst-2?adjust_creative=BEubh_gw8oLY50Nph3EDhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BEubh_gw8oLY50Nph3EDhg',
#    'review_count': 1222,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7433662414551,
#     'longitude': -73.8876037597656},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '7708 Woodside Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Elmhurst',
#     'zip_code': '11373',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['7708 Woodside Ave', 'Elmhurst, NY 11373']},
#    'phone': '+17184240844',
#    'display_phone': '(718) 424-0844',
#    'distance': 3222.317210809843},
#   {'id': '-YazuZbXAM_NOny8LpLQpQ',
#    'alias': 'bkny-thai-restaurant-bayside',
#    'name': 'BKNY Thai Restaurant',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/glVWdfDHW-eu4KhXWP3QMw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bkny-thai-restaurant-bayside?adjust_creative=BEubh_gw8oLY50Nph3EDhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BEubh_gw8oLY50Nph3EDhg',
#    'review_count': 1317,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'salad', 'title': 'Salad'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7530184239866,
#     'longitude': -73.780074009384},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '47-11 Francis Lewis Blvd',
#     'address2': None,
#     'address3': '',
#     'city': 'Bayside',
#     'zip_code': '11361',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['47-11 Francis Lewis Blvd', 'Bayside, NY 11361']},
#    'phone': '+17182811900',
#    'display_phone': '(718) 281-1900',
#    'distance': 6582.441577772174},
#   {'id': '1E7lCNaRAM1Da0vkt5rcvw',
#    'alias': 'thai-mission-maspeth',
#    'name': 'Thai Mission',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/OTi0qCJS2HAyviRUwg-Qtw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/thai-mission-maspeth?adjust_creative=BEubh_gw8oLY50Nph3EDhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BEubh_gw8oLY50Nph3EDhg',
#    'review_count': 29,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.72779, 'longitude': -73.89279},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '70-11 Grand Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Maspeth',
#     'zip_code': '11378',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['70-11 Grand Ave', 'Maspeth, NY 11378']},
#    'phone': '+19293280328',
#    'display_phone': '(929) 328-0328',
#    'distance': 3390.6012918832753},
#   {'id': '1ubEg-rrSE8IWXl6lJzIGw',
#    'alias': 'nur-thai-rego-park',
#    'name': 'Nur Thai',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/wKL4Mnmig42Youp-9eYUIg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nur-thai-rego-park?adjust_creative=BEubh_gw8oLY50Nph3EDhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BEubh_gw8oLY50Nph3EDhg',
#    'review_count': 561,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7235516378586,
#     'longitude': -73.868817789544},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '63-32 Woodhaven Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Rego Park',
#     'zip_code': '11374',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['63-32 Woodhaven Blvd', 'Rego Park, NY 11374']},
#    'phone': '+17182556141',
#    'display_phone': '(718) 255-6141',
#    'distance': 1608.1819342053043},
#   {'id': 'OVAV0k2O1kqeuRFyt95qzg',
#    'alias': 'ma-kin-middle-village-3',
#    'name': 'Ma Kin',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/HKS9ClA3DITKpnzWjhFm6w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ma-kin-middle-village-3?adjust_creative=BEubh_gw8oLY50Nph3EDhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BEubh_gw8oLY50Nph3EDhg',
#    'review_count': 92,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7130368, 'longitude': -73.8775219},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '7419 Metropolitan Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Middle Village',
#     'zip_code': '11379',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['7419 Metropolitan Ave', 'Middle Village, NY 11379']},
#    'phone': '+13475071234',
#    'display_phone': '(347) 507-1234',
#    'distance': 2915.288989938397},
#   {'id': 'a-Bq_yXFVk2PptoWpmry3w',
#    'alias': 'pye-boat-noodle-astoria',
#    'name': 'Pye Boat Noodle',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/jxPnZAwHuRciVqUAd14P4Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pye-boat-noodle-astoria?adjust_creative=BEubh_gw8oLY50Nph3EDhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BEubh_gw8oLY50Nph3EDhg',
#    'review_count': 837,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.76043, 'longitude': -73.92152},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '35-13 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'Astoria',
#     'zip_code': '11106',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['35-13 Broadway', 'Astoria, NY 11106']},
#    'phone': '+17186852329',
#    'display_phone': '(718) 685-2329',
#    'distance': 6625.086426070104},
#   {'id': 'oNN202L_XcNM-tuDHlgkfg',
#    'alias': 'boon-chu-thai-place-elmhurst',
#    'name': 'Boon Chu Thai Place',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/0ffVw7NKAcTDUIPfd5tUwA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/boon-chu-thai-place-elmhurst?adjust_creative=BEubh_gw8oLY50Nph3EDhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BEubh_gw8oLY50Nph3EDhg',
#    'review_count': 313,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.740638, 'longitude': -73.879645},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '83-18 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'Elmhurst',
#     'zip_code': '11373',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['83-18 Broadway', 'Elmhurst, NY 11373']},
#    'phone': '+17188986836',
#    'display_phone': '(718) 898-6836',
#    'distance': 2477.7303260455205},
#   {'id': 'STx4mlpKJVrjd6eZu4yDIw',
#    'alias': 'heng-thai-long-island-city',
#    'name': 'Heng Thai',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/TNglrhhC7IGOBrdkTu-h-g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/heng-thai-long-island-city?adjust_creative=BEubh_gw8oLY50Nph3EDhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BEubh_gw8oLY50Nph3EDhg',
#    'review_count': 10,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.74491469312005,
#     'longitude': -73.94774386999885},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '23-06 Jackson Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Long Island City',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['23-06 Jackson Ave', 'Long Island City, NY 11101']},
#    'phone': '+17187060999',
#    'display_phone': '(718) 706-0999',
#    'distance': 8134.151172667756},
#   {'id': '5pzc2GdvdmqiLRSdjHnnKw',
#    'alias': 'bangkok-avenue-little-neck-2',
#    'name': 'Bangkok Avenue',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/-6MNVU7V930qB3PvdLHKAw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bangkok-avenue-little-neck-2?adjust_creative=BEubh_gw8oLY50Nph3EDhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BEubh_gw8oLY50Nph3EDhg',
#    'review_count': 86,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.77135, 'longitude': -73.73529},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '253-21 Northern Blvd',
#     'address2': None,
#     'address3': '',
#     'city': 'Little Neck',
#     'zip_code': '11362',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['253-21 Northern Blvd', 'Little Neck, NY 11362']},
#    'phone': '+19143033388',
#    'display_phone': '(914) 303-3388',
#    'distance': 10849.613791106447},
#   {'id': '1svF14BUYt_Wc0XA3nMxdw',
#    'alias': 'cha-lom-thai-flushing',
#    'name': 'Cha Lom Thai',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/LUcuIr0hXhAy8DMUMbClFA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cha-lom-thai-flushing?adjust_creative=BEubh_gw8oLY50Nph3EDhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BEubh_gw8oLY50Nph3EDhg',
#    'review_count': 59,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7663429058334,
#     'longitude': -73.7893586550144},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '33-47 Francis Lewis Blvd',
#     'address2': None,
#     'address3': '',
#     'city': 'Flushing',
#     'zip_code': '11358',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['33-47 Francis Lewis Blvd', 'Flushing, NY 11358']},
#    'phone': '+17182696821',
#    'display_phone': '(718) 269-6821',
#    'distance': 6606.083966623151},
#   {'id': 'PPQSf_1JWkbjFHi1S0nSNA',
#    'alias': 'lamoon-elmhurst',
#    'name': 'Lamoon',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/YNrzpdKbmrGLFOtPUwFW6Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lamoon-elmhurst?adjust_creative=BEubh_gw8oLY50Nph3EDhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BEubh_gw8oLY50Nph3EDhg',
#    'review_count': 268,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.742890245749, 'longitude': -73.883034010715},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '8140 Broadway',
#     'address2': '',
#     'address3': None,
#     'city': 'Elmhurst',
#     'zip_code': '11373',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['8140 Broadway', 'Elmhurst, NY 11373']},
#    'phone': '+19177451168',
#    'display_phone': '(917) 745-1168',
#    'distance': 2843.1620995374224},
#   {'id': 'Ve_iFpnhL8zN789ZL2jnxQ',
#    'alias': 'uthai-rego-park',
#    'name': 'UThai',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/EyX6yAydMLYFXZc7dY7PRQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/uthai-rego-park?adjust_creative=BEubh_gw8oLY50Nph3EDhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BEubh_gw8oLY50Nph3EDhg',
#    'review_count': 219,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'vegan', 'title': 'Vegan'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7282415, 'longitude': -73.8639467},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '63-55 Wetherole St',
#     'address2': None,
#     'address3': '',
#     'city': 'Rego Park',
#     'zip_code': '11374',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['63-55 Wetherole St', 'Rego Park, NY 11374']},
#    'phone': '+17188971575',
#    'display_phone': '(718) 897-1575',
#    'distance': 1001.8808045720075},
#   {'id': 'tVB11pOiDhPWlt_o6ylMNg',
#    'alias': 'enthaice-thai-kitchen-astoria',
#    'name': 'Enthaice Thai Kitchen',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/poiYY93PvnCGFXQAEvO-Ng/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/enthaice-thai-kitchen-astoria?adjust_creative=BEubh_gw8oLY50Nph3EDhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BEubh_gw8oLY50Nph3EDhg',
#    'review_count': 695,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'chicken_wings', 'title': 'Chicken Wings'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7630889337809,
#     'longitude': -73.9213237166405},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '33-20 31st Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Astoria',
#     'zip_code': '11106',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['33-20 31st Ave', 'Astoria, NY 11106']},
#    'phone': '+17189321111',
#    'display_phone': '(718) 932-1111',
#    'distance': 6755.95967403878},
#   {'id': 'inftQdKaEEiqQ323AlomXg',
#    'alias': 'dek-sen-elmhurst-2',
#    'name': 'Dek Sen',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/VV_1YWKJXD_BEvAfQ2-wGw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dek-sen-elmhurst-2?adjust_creative=BEubh_gw8oLY50Nph3EDhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BEubh_gw8oLY50Nph3EDhg',
#    'review_count': 278,
#    'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.741714, 'longitude': -73.878689},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '8608 Whitney Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Elmhurst',
#     'zip_code': '11373',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['8608 Whitney Ave', 'Elmhurst, NY 11373']},
#    'phone': '+17182055181',
#    'display_phone': '(718) 205-5181',
#    'distance': 2452.1963359930987},
#   {'id': 'a23bfZBVjIhV32Em4hKHAA',
#    'alias': 'the-buffs-long-island-city-4',
#    'name': 'The Buffs',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/lQID-gz3kJ6Gw-Yr8rLVKQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-buffs-long-island-city-4?adjust_creative=BEubh_gw8oLY50Nph3EDhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BEubh_gw8oLY50Nph3EDhg',
#    'review_count': 106,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7556342, 'longitude': -73.9417121},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1313 40th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Long Island City',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1313 40th Ave', 'Long Island City, NY 11101']},
#    'phone': '+17183612362',
#    'display_phone': '(718) 361-2362',
#    'distance': 7918.772733558018},
#   {'id': 'CpY77cDN1KS5EdiXMmWovw',
#    'alias': 'house-of-thai-long-island-city-4',
#    'name': 'House of Thai',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/uZJDECEq7QBfrSIfyrPsRQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/house-of-thai-long-island-city-4?adjust_creative=BEubh_gw8oLY50Nph3EDhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BEubh_gw8oLY50Nph3EDhg',
#    'review_count': 301,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7535257695712,
#     'longitude': -73.9377629319284},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '2501 40th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Long Island City',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2501 40th Ave', 'Long Island City, NY 11101']},
#    'phone': '+19295220247',
#    'display_phone': '(929) 522-0247',
#    'distance': 7562.962070152043},
#   {'id': 'PyaeHq_UAu6nazGiy0XAnw',
#    'alias': 'ginger-and-lemongrass-whitestone',
#    'name': 'Ginger and Lemongrass',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/rc7pZR40ZmAVzeenf48eZA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ginger-and-lemongrass-whitestone?adjust_creative=BEubh_gw8oLY50Nph3EDhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BEubh_gw8oLY50Nph3EDhg',
#    'review_count': 801,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#     {'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7892691, 'longitude': -73.813717},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1253 150th St',
#     'address2': None,
#     'address3': '',
#     'city': 'Whitestone',
#     'zip_code': '11357',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1253 150th St', 'Whitestone, NY 11357']},
#    'phone': '+13477324720',
#    'display_phone': '(347) 732-4720',
#    'distance': 7222.985916370918},
#   {'id': 'yCJHIM-PWl54K53ACOpoNg',
#    'alias': 'hug-esan-elmhurst',
#    'name': 'Hug Esan',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/6solnO-f4-uAP7irlf1MZA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hug-esan-elmhurst?adjust_creative=BEubh_gw8oLY50Nph3EDhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BEubh_gw8oLY50Nph3EDhg',
#    'review_count': 169,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7436465, 'longitude': -73.8873753},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '77-16 Woodside Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Elmhurst',
#     'zip_code': '11373',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['77-16 Woodside Ave', 'Elmhurst, NY 11373']},
#    'phone': '+19293280392',
#    'display_phone': '(929) 328-0392',
#    'distance': 3209.1609507515063},
#   {'id': 'm2_ZNFos5ugAwe8ft8eaEw',
#    'alias': 'eim-khao-mun-kai-elmhurst-elmhurst',
#    'name': 'Eim Khao Mun Kai Elmhurst',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/JqeuGqrZxCPGVowAEs8XFQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/eim-khao-mun-kai-elmhurst-elmhurst?adjust_creative=BEubh_gw8oLY50Nph3EDhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BEubh_gw8oLY50Nph3EDhg',
#    'review_count': 457,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'hainan', 'title': 'Hainan'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7429414097644,
#     'longitude': -73.8832733356575},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '81-32 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'Elmhurst',
#     'zip_code': '11373',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['81-32 Broadway', 'Elmhurst, NY 11373']},
#    'phone': '+17184247156',
#    'display_phone': '(718) 424-7156',
#    'distance': 2863.74521041377},
#   {'id': 'kXuubLd6s3GidpqU3psPdw',
#    'alias': 'chao-thai-elmhurst-3',
#    'name': 'Chao Thai',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Sq1y11AFR9zp81X0aH9vKw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chao-thai-elmhurst-3?adjust_creative=BEubh_gw8oLY50Nph3EDhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BEubh_gw8oLY50Nph3EDhg',
#    'review_count': 379,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7414656, 'longitude': -73.8801273},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '8503 Whitney Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Elmhurst',
#     'zip_code': '11373',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['8503 Whitney Ave', 'Elmhurst, NY 11373']},
#    'phone': '+17184244999',
#    'display_phone': '(718) 424-4999',
#    'distance': 2568.855535856452},
#   {'id': 'hA5QUlrSjpxMZ90Kof0bgA',
#    'alias': 'khao-kang-elmhurst',
#    'name': 'Khao Kang',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/vfRK27R36XLI4wHpZr6bHQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/khao-kang-elmhurst?adjust_creative=BEubh_gw8oLY50Nph3EDhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BEubh_gw8oLY50Nph3EDhg',
#    'review_count': 244,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.743269, 'longitude': -73.888039},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '7620 Woodside Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Elmhurst',
#     'zip_code': '11373',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['7620 Woodside Ave', 'Elmhurst, NY 11373']},
#    'phone': '+17188061807',
#    'display_phone': '(718) 806-1807',
#    'distance': 3242.7336966969283},
#   {'id': 'a5H9p1B6m6WPVjakPylvdA',
#    'alias': 'spicy-shallot-elmhurst',
#    'name': 'Spicy Shallot',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/OzUSMfiNLzDNthJuYxni0Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/spicy-shallot-elmhurst?adjust_creative=BEubh_gw8oLY50Nph3EDhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BEubh_gw8oLY50Nph3EDhg',
#    'review_count': 633,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7437053273707,
#     'longitude': -73.8878916857991},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '7701 Woodside Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Elmhurst',
#     'zip_code': '11373',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['7701 Woodside Ave', 'Elmhurst, NY 11373']},
#    'phone': '+17186725266',
#    'display_phone': '(718) 672-5266',
#    'distance': 3251.3867012082496},
#   {'id': 'rehmlZmUNL2AthW-VTXJJQ',
#    'alias': 'tasty-thai-ridgewood',
#    'name': 'Tasty Thai',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/NX0ocs11fl3Dj1kTmpBrRw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tasty-thai-ridgewood?adjust_creative=BEubh_gw8oLY50Nph3EDhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BEubh_gw8oLY50Nph3EDhg',
#    'review_count': 86,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.69984, 'longitude': -73.89958},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '72-04 Forest Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Ridgewood',
#     'zip_code': '11385',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['72-04 Forest Ave', 'Ridgewood, NY 11385']},
#    'phone': '+19179090937',
#    'display_phone': '(917) 909-0937',
#    'distance': 5281.3840549926945},
#   {'id': 'zRQNaDUoWTInc2tqndSJVA',
#    'alias': 'thai-101-bayside',
#    'name': 'Thai 101',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/dvejY_8barqkhtUQt35Hkw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/thai-101-bayside?adjust_creative=BEubh_gw8oLY50Nph3EDhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BEubh_gw8oLY50Nph3EDhg',
#    'review_count': 306,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.76488, 'longitude': -73.77133},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '39-15 Bell Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Bayside',
#     'zip_code': '11361',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['39-15 Bell Blvd', 'Bayside, NY 11361']},
#    'phone': '+17186318600',
#    'display_phone': '(718) 631-8600',
#    'distance': 7803.89291133938},
#   {'id': 'YMcDo3UccCPvIJrQ5Yt9Yw',
#    'alias': 'chám-thai-cuisine-ridgewood',
#    'name': 'Chám Thai Cuisine',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/_INscq_GSjWwiY03XfcQbA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ch%C3%A1m-thai-cuisine-ridgewood?adjust_creative=BEubh_gw8oLY50Nph3EDhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BEubh_gw8oLY50Nph3EDhg',
#    'review_count': 48,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7025939, 'longitude': -73.901464},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '881 Woodward Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Ridgewood',
#     'zip_code': '11385',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['881 Woodward Ave', 'Ridgewood, NY 11385']},
#    'phone': '+17188944404',
#    'display_phone': '(718) 894-4404',
#    'distance': 5205.517479140647},
#   {'id': 'wEawMdWT7UtZjEmmMTBiGA',
#    'alias': 'saranrom-thai-elmhurst-2',
#    'name': 'Saranrom Thai',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/kfH2mX_qFCnGegh9CUY_rg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/saranrom-thai-elmhurst-2?adjust_creative=BEubh_gw8oLY50Nph3EDhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BEubh_gw8oLY50Nph3EDhg',
#    'review_count': 32,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7431528, 'longitude': -73.8836694},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '8110 Broadway',
#     'address2': None,
#     'address3': '',
#     'city': 'Elmhurst',
#     'zip_code': '11373',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['8110 Broadway', 'Elmhurst, NY 11373']},
#    'phone': '+19178326672',
#    'display_phone': '(917) 832-6672',
#    'distance': 2905.2906392679156},
#   {'id': 'OR9oqAJW-U5ZnqhwH12Nuw',
#    'alias': 'khao-nom-elmhurst',
#    'name': 'Khao Nom',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/fiPmRRzFIz4WRhuyAyGXXQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/khao-nom-elmhurst?adjust_creative=BEubh_gw8oLY50Nph3EDhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BEubh_gw8oLY50Nph3EDhg',
#    'review_count': 116,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7432731562959,
#     'longitude': -73.8879961885031},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '42-06 77th St',
#     'address2': '',
#     'address3': None,
#     'city': 'Elmhurst',
#     'zip_code': '11373',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['42-06 77th St', 'Elmhurst, NY 11373']},
#    'phone': '+19292080108',
#    'display_phone': '(929) 208-0108',
#    'distance': 3250.841753204315},
#   {'id': 'toykv8K0yg8qtvZSXRQ5bg',
#    'alias': 'pochana-thai-kitchen-astoria-2',
#    'name': 'Pochana Thai Kitchen',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/5hfYhHZOsD9SRICjUaFpYQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pochana-thai-kitchen-astoria-2?adjust_creative=BEubh_gw8oLY50Nph3EDhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BEubh_gw8oLY50Nph3EDhg',
#    'review_count': 193,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.765733, 'longitude': -73.91932},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '33-16 30th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Astoria',
#     'zip_code': '11103',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['33-16 30th Ave', 'Astoria, NY 11103']},
#    'phone': '+17189569559',
#    'display_phone': '(718) 956-9559',
#    'distance': 6773.2440684776475},
#   {'id': 'dnCRiUZWgu5ZI4Q-Z-az6Q',
#    'alias': 'thai-diva-cuisine-woodside-3',
#    'name': 'Thai Diva Cuisine',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/FAxltkvgVnPp87i9Uq90Ew/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/thai-diva-cuisine-woodside-3?adjust_creative=BEubh_gw8oLY50Nph3EDhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BEubh_gw8oLY50Nph3EDhg',
#    'review_count': 140,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'soup', 'title': 'Soup'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7414512, 'longitude': -73.9190131},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '45-53 46th St',
#     'address2': None,
#     'address3': '',
#     'city': 'Woodside',
#     'zip_code': '11377',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['45-53 46th St', 'Woodside, NY 11377']},
#    'phone': '+19292080282',
#    'display_phone': '(929) 208-0282',
#    'distance': 5684.506606279269},
#   {'id': 'ipxeCjihDqXTMkuPe-CQ4A',
#    'alias': 'arunee-thai-jackson-heights',
#    'name': 'Arunee Thai',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/yBzXFJre13F2BtJNRiWAlA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/arunee-thai-jackson-heights?adjust_creative=BEubh_gw8oLY50Nph3EDhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BEubh_gw8oLY50Nph3EDhg',
#    'review_count': 317,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7494503, 'longitude': -73.8873621},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '78-23 37th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Jackson Heights',
#     'zip_code': '11372',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['78-23 37th Ave', 'Jackson Heights, NY 11372']},
#    'phone': '+17182055559',
#    'display_phone': '(718) 205-5559',
#    'distance': 3529.3232402943213},
#   {'id': '8-dc942sz-prIeepAkHLJA',
#    'alias': 'zenith-thai-restaurant-ridgewood',
#    'name': 'Zenith Thai Restaurant',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/P5WjD6_4bZyV6AVgkeceaw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/zenith-thai-restaurant-ridgewood?adjust_creative=BEubh_gw8oLY50Nph3EDhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BEubh_gw8oLY50Nph3EDhg',
#    'review_count': 113,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7023726, 'longitude': -73.8952926},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '7002 Fresh Pond Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Ridgewood',
#     'zip_code': '11385',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['7002 Fresh Pond Rd', 'Ridgewood, NY 11385']},
#    'phone': '+17184978899',
#    'display_phone': '(718) 497-8899',
#    'distance': 4825.743443483346},
#   {'id': 'Eyn7hQENF8R9DrBwBHO6lQ',
#    'alias': 'pata-cafe-elmhurst',
#    'name': 'Pata Cafe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/XaAZQtUInh_RNGATh7ImpA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pata-cafe-elmhurst?adjust_creative=BEubh_gw8oLY50Nph3EDhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BEubh_gw8oLY50Nph3EDhg',
#    'review_count': 73,
#    'categories': [{'alias': 'bubbletea', 'title': 'Bubble Tea'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7326341, 'longitude': -73.8769762},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '5614 Van Horn St',
#     'address2': None,
#     'address3': '',
#     'city': 'Elmhurst',
#     'zip_code': '11373',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['5614 Van Horn St', 'Elmhurst, NY 11373']},
#    'phone': '+13474697142',
#    'display_phone': '(347) 469-7142',
#    'distance': 2013.709004982964},
#   {'id': '1wdJ1vJR_Z1vJebQGlZU3Q',
#    'alias': 'krung-tep-thai-bistro-great-neck-plaza',
#    'name': 'Krung Tep Thai Bistro',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Nwo0m4I7O95U2Kp9-JRoIQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/krung-tep-thai-bistro-great-neck-plaza?adjust_creative=BEubh_gw8oLY50Nph3EDhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BEubh_gw8oLY50Nph3EDhg',
#    'review_count': 223,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.78661, 'longitude': -73.725858},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '23 S Middle Neck Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Great Neck Plaza',
#     'zip_code': '11021',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['23 S Middle Neck Rd', 'Great Neck Plaza, NY 11021']},
#    'phone': '+15164989889',
#    'display_phone': '(516) 498-9889',
#    'distance': 12337.29866702809},
#   {'id': '2ZBEE_MJeRdLD1NLiNTnCQ',
#    'alias': 'thailands-center-point-woodside-2',
#    'name': "Thailand's Center Point",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/o99eLojQrJOaEe1keKZEug/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/thailands-center-point-woodside-2?adjust_creative=BEubh_gw8oLY50Nph3EDhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BEubh_gw8oLY50Nph3EDhg',
#    'review_count': 196,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.746738, 'longitude': -73.900162},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '63-19 39th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Woodside',
#     'zip_code': '11377',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['63-19 39th Ave', 'Woodside, NY 11377']},
#    'phone': '+17186516888',
#    'display_phone': '(718) 651-6888',
#    'distance': 4333.1887147697735},
#   {'id': 'ET4xGd-SQ6gs9lce4xVpQg',
#    'alias': 'tum-thai-cuisine-rockville-centre',
#    'name': 'Tum Thai Cuisine',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/0keHJi1yLq97gnDyCeM7UQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tum-thai-cuisine-rockville-centre?adjust_creative=BEubh_gw8oLY50Nph3EDhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BEubh_gw8oLY50Nph3EDhg',
#    'review_count': 641,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.65591, 'longitude': -73.64574},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '274 Merrick Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Rockville Centre',
#     'zip_code': '11570',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['274 Merrick Rd', 'Rockville Centre, NY 11570']},
#    'phone': '+15165435078',
#    'display_phone': '(516) 543-5078',
#    'distance': 19384.513491944435},
#   {'id': 'nu239sXQUGjcGFhZ3AdJmQ',
#    'alias': 'erawan-thai-cuisine-bayside',
#    'name': 'Erawan Thai Cuisine',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/x_vmcrpshZxNmtw9sKHzwA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/erawan-thai-cuisine-bayside?adjust_creative=BEubh_gw8oLY50Nph3EDhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BEubh_gw8oLY50Nph3EDhg',
#    'review_count': 346,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.761821, 'longitude': -73.769775},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '4231 Bell Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Bayside',
#     'zip_code': '11361',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['4231 Bell Blvd', 'Bayside, NY 11361']},
#    'phone': '+17184282112',
#    'display_phone': '(718) 428-2112',
#    'distance': 7766.294526950914},
#   {'id': '2pJ782hnKTK0MWbc0H7EDw',
#    'alias': 'ditmars-thai-astoria',
#    'name': 'Ditmars Thai',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/P4ei6AZRi77oR6HcHLJMbg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ditmars-thai-astoria?adjust_creative=BEubh_gw8oLY50Nph3EDhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BEubh_gw8oLY50Nph3EDhg',
#    'review_count': 12,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.77473, 'longitude': -73.90825},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '35-13 Ditmars Blvd',
#     'address2': '',
#     'address3': None,
#     'city': 'Astoria',
#     'zip_code': '11105',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['35-13 Ditmars Blvd', 'Astoria, NY 11105']},
#    'phone': '+17182694549',
#    'display_phone': '(718) 269-4549',
#    'distance': 6703.073797984971},
#   {'id': 'QWskQ2QpR8bmza2FRFziOQ',
#    'alias': 'asian-fortune-restaurant-forest-hills',
#    'name': 'Asian Fortune Restaurant',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Av0ZXxYsKSXnZ8z182gh0g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/asian-fortune-restaurant-forest-hills?adjust_creative=BEubh_gw8oLY50Nph3EDhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BEubh_gw8oLY50Nph3EDhg',
#    'review_count': 114,
#    'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'},
#     {'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7244621, 'longitude': -73.8493213},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '103-35 Queens Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Forest Hills',
#     'zip_code': '11375',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['103-35 Queens Blvd', 'Forest Hills, NY 11375']},
#    'phone': '+17188306313',
#    'display_phone': '(718) 830-6313',
#    'distance': 851.8262088216507},
#   {'id': 'khvnn7cpiYSpe80ue5YLvg',
#    'alias': 'ddee-thai-astoria',
#    'name': 'Ddee Thai',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/mVpYungatdQ1AFuujOjTdA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ddee-thai-astoria?adjust_creative=BEubh_gw8oLY50Nph3EDhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BEubh_gw8oLY50Nph3EDhg',
#    'review_count': 37,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.762909, 'longitude': -73.91325},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '42-06 30th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Astoria',
#     'zip_code': '11103',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['42-06 30th Ave', 'Astoria, NY 11103']},
#    'phone': '+17186261222',
#    'display_phone': '(718) 626-1222',
#    'distance': 6173.635697332506},
#   {'id': 'MxMWPaC30sRkPKit_Omz2A',
#    'alias': 'khun-noo-thai-noodle-house-woodside',
#    'name': 'Khun Noo Thai Noodle House',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/85O4rR5ovWEeOa7sy1El2Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/khun-noo-thai-noodle-house-woodside?adjust_creative=BEubh_gw8oLY50Nph3EDhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BEubh_gw8oLY50Nph3EDhg',
#    'review_count': 51,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.74568, 'longitude': -73.91261},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '51-20 Skillman Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Woodside',
#     'zip_code': '11377',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['51-20 Skillman Ave', 'Woodside, NY 11377']},
#    'phone': '+17184268162',
#    'display_phone': '(718) 426-8162',
#    'distance': 5278.326423160265},
#   {'id': 'YIgBb6jb_KV0-nbYZ1oPig',
#    'alias': 'barn-na-thai-ridgewood',
#    'name': 'BARN NA THAI',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/GAI2zkiVLyalqT0cX3K3vg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/barn-na-thai-ridgewood?adjust_creative=BEubh_gw8oLY50Nph3EDhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BEubh_gw8oLY50Nph3EDhg',
#    'review_count': 16,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.71012, 'longitude': -73.89958},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '6402 Fresh Pond Rd',
#     'address2': None,
#     'address3': None,
#     'city': 'RIDGEWOOD',
#     'zip_code': '11385',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['6402 Fresh Pond Rd', 'RIDGEWOOD, NY 11385']},
#    'phone': '+19293878065',
#    'display_phone': '(929) 387-8065',
#    'distance': 4594.843164144977},
#   {'id': 'SkYcO8FaqYgoP-66g58OMw',
#    'alias': 'thai-pot-forest-hills',
#    'name': 'Thai Pot',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Qu_oE3bTpWt-pJw8r4LXxw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/thai-pot-forest-hills?adjust_creative=BEubh_gw8oLY50Nph3EDhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BEubh_gw8oLY50Nph3EDhg',
#    'review_count': 246,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.7247545048924,
#     'longitude': -73.8498401641846},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '103-07 Queens Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Forest Hills',
#     'zip_code': '11375',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['103-07 Queens Blvd', 'Forest Hills, NY 11375']},
#    'phone': '+17188973898',
#    'display_phone': '(718) 897-3898',
#    'distance': 788.0501952017784},
#   {'id': 'qrydcGQpeDP_1oFvx3qOeg',
#    'alias': 'somtum-der-new-york',
#    'name': 'Somtum Der',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/85AftnoxLOq0T0HKHPSdgg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/somtum-der-new-york?adjust_creative=BEubh_gw8oLY50Nph3EDhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BEubh_gw8oLY50Nph3EDhg',
#    'review_count': 753,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7252151982238,
#     'longitude': -73.9842741682317},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '85 Ave A',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['85 Ave A', 'New York, NY 10009']},
#    'phone': '+12122608570',
#    'display_phone': '(212) 260-8570',
#    'distance': 11096.694980469541},
#   {'id': 'zENn0_yDJEdLoHyivXb2xw',
#    'alias': 'black-thai-jackson-heights-4',
#    'name': 'Black Thai',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/kxJrShs7FqI0OaNE1d01aw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/black-thai-jackson-heights-4?adjust_creative=BEubh_gw8oLY50Nph3EDhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BEubh_gw8oLY50Nph3EDhg',
#    'review_count': 290,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7553269, 'longitude': -73.8860092},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '81-16 Northern Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Jackson Heights',
#     'zip_code': '11372',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['81-16 Northern Blvd', 'Jackson Heights, NY 11372']},
#    'phone': '+17187798424',
#    'display_phone': '(718) 779-8424',
#    'distance': 3827.0847177331707}],
#  'total': 2600,
#  'region': {'center': {'longitude': -73.85284423828125,
#    'latitude': 40.73146603137887}}}

# %%
response.json()
# Out:
# {'businesses': [{'id': 'uazg6WhYVOw3jhWCG_MDBg',
#    'alias': 'sup-thai-kitchen-fresh-meadows',
#    'name': 'Sup Thai Kitchen',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ouTt4JK93LOG0P7fSG1r7g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sup-thai-kitchen-fresh-meadows?adjust_creative=BEubh_gw8oLY50Nph3EDhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BEubh_gw8oLY50Nph3EDhg',
#    'review_count': 373,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7266838, 'longitude': -73.7894371},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '178-19 Union Tpke',
#     'address2': None,
#     'address3': '',
#     'city': 'Fresh Meadows',
#     'zip_code': '11366',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['178-19 Union Tpke', 'Fresh Meadows, NY 11366']},
#    'phone': '+17184874449',
#    'display_phone': '(718) 487-4449',
#    'distance': 5378.159709707153},
#   {'id': 'cegA4jf16vEt7NCQ7cpu2w',
#    'alias': 'kind-fresh-meadows',
#    'name': "Kin'd",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/3rnKMO-RGXBAVYXAgffmwQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kind-fresh-meadows?adjust_creative=BEubh_gw8oLY50Nph3EDhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BEubh_gw8oLY50Nph3EDhg',
#    'review_count': 767,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.73031, 'longitude': -73.77814},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '192-03 Union Tpke',
#     'address2': '',
#     'address3': None,
#     'city': 'Fresh Meadows',
#     'zip_code': '11366',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['192-03 Union Tpke', 'Fresh Meadows, NY 11366']},
#    'phone': '+17184680888',
#    'display_phone': '(718) 468-0888',
#    'distance': 6273.193942408963},
#   {'id': '0L03onqNwxWLrbb_FCK79A',
#    'alias': 'sripraphai-thai-restaurant-woodside',
#    'name': 'SriPraPhai Thai Restaurant',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/DBYmdu8aWPzPWKJzvPm-aQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sripraphai-thai-restaurant-woodside?adjust_creative=BEubh_gw8oLY50Nph3EDhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BEubh_gw8oLY50Nph3EDhg',
#    'review_count': 2380,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7464987, 'longitude': -73.8992328},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '64-13 39th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Woodside',
#     'zip_code': '11377',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['64-13 39th Ave', 'Woodside, NY 11377']},
#    'phone': '+17188999599',
#    'display_phone': '(718) 899-9599',
#    'distance': 4250.747809627073},
#   {'id': 'gr3wUszE1972q0GBkmwEXQ',
#    'alias': 'bangkok-cuisine-forest-hills',
#    'name': 'Bangkok Cuisine',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/8vTa_qflOZVu30D0k0HSTg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bangkok-cuisine-forest-hills?adjust_creative=BEubh_gw8oLY50Nph3EDhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BEubh_gw8oLY50Nph3EDhg',
#    'review_count': 421,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.720954, 'longitude': -73.845238},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '10718 70th Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Forest Hills',
#     'zip_code': '11375',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['10718 70th Rd', 'Forest Hills, NY 11375']},
#    'phone': '+17182614005',
#    'display_phone': '(718) 261-4005',
#    'distance': 1329.980593467087},
#   {'id': 'jMb34zhfkqoW866F10hf1Q',
#    'alias': 'grace-thai-restaurant-elmhurst',
#    'name': 'Grace Thai Restaurant',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/JtXzAAG2jsoperWNGOANSA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/grace-thai-restaurant-elmhurst?adjust_creative=BEubh_gw8oLY50Nph3EDhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BEubh_gw8oLY50Nph3EDhg',
#    'review_count': 52,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.736905, 'longitude': -73.865734},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '5617 Junction Blvd',
#     'address2': None,
#     'address3': '',
#     'city': 'Elmhurst',
#     'zip_code': '11373',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['5617 Junction Blvd', 'Elmhurst, NY 11373']},
#    'phone': '+19294633693',
#    'display_phone': '(929) 463-3693',
#    'distance': 1241.9783887099397},
#   {'id': '3GMHPnrkFAcqffw3T7JSdQ',
#    'alias': 'kitchen-79-jackson-heights',
#    'name': 'Kitchen 79',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ip9F8-pOstZmt7_8T_46Jg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kitchen-79-jackson-heights?adjust_creative=BEubh_gw8oLY50Nph3EDhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BEubh_gw8oLY50Nph3EDhg',
#    'review_count': 629,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.747551, 'longitude': -73.8868866},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '37-70 79th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Jackson Heights',
#     'zip_code': '11372',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['37-70 79th St', 'Jackson Heights, NY 11372']},
#    'phone': '+17188036227',
#    'display_phone': '(718) 803-6227',
#    'distance': 3388.369692606335},
#   {'id': 'fRO4Fwe5uRAajMcTwLbVkA',
#    'alias': 'ayada-thai-elmhurst-2',
#    'name': 'Ayada Thai',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/qybFSiSVmsTTXx5fmX3BNQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ayada-thai-elmhurst-2?adjust_creative=BEubh_gw8oLY50Nph3EDhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BEubh_gw8oLY50Nph3EDhg',
#    'review_count': 1222,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7433662414551,
#     'longitude': -73.8876037597656},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '7708 Woodside Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Elmhurst',
#     'zip_code': '11373',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['7708 Woodside Ave', 'Elmhurst, NY 11373']},
#    'phone': '+17184240844',
#    'display_phone': '(718) 424-0844',
#    'distance': 3222.317210809843},
#   {'id': '-YazuZbXAM_NOny8LpLQpQ',
#    'alias': 'bkny-thai-restaurant-bayside',
#    'name': 'BKNY Thai Restaurant',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/glVWdfDHW-eu4KhXWP3QMw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bkny-thai-restaurant-bayside?adjust_creative=BEubh_gw8oLY50Nph3EDhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BEubh_gw8oLY50Nph3EDhg',
#    'review_count': 1317,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'salad', 'title': 'Salad'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7530184239866,
#     'longitude': -73.780074009384},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '47-11 Francis Lewis Blvd',
#     'address2': None,
#     'address3': '',
#     'city': 'Bayside',
#     'zip_code': '11361',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['47-11 Francis Lewis Blvd', 'Bayside, NY 11361']},
#    'phone': '+17182811900',
#    'display_phone': '(718) 281-1900',
#    'distance': 6582.441577772174},
#   {'id': '1E7lCNaRAM1Da0vkt5rcvw',
#    'alias': 'thai-mission-maspeth',
#    'name': 'Thai Mission',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/OTi0qCJS2HAyviRUwg-Qtw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/thai-mission-maspeth?adjust_creative=BEubh_gw8oLY50Nph3EDhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BEubh_gw8oLY50Nph3EDhg',
#    'review_count': 29,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.72779, 'longitude': -73.89279},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '70-11 Grand Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Maspeth',
#     'zip_code': '11378',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['70-11 Grand Ave', 'Maspeth, NY 11378']},
#    'phone': '+19293280328',
#    'display_phone': '(929) 328-0328',
#    'distance': 3390.6012918832753},
#   {'id': '1ubEg-rrSE8IWXl6lJzIGw',
#    'alias': 'nur-thai-rego-park',
#    'name': 'Nur Thai',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/wKL4Mnmig42Youp-9eYUIg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nur-thai-rego-park?adjust_creative=BEubh_gw8oLY50Nph3EDhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BEubh_gw8oLY50Nph3EDhg',
#    'review_count': 561,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7235516378586,
#     'longitude': -73.868817789544},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '63-32 Woodhaven Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Rego Park',
#     'zip_code': '11374',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['63-32 Woodhaven Blvd', 'Rego Park, NY 11374']},
#    'phone': '+17182556141',
#    'display_phone': '(718) 255-6141',
#    'distance': 1608.1819342053043},
#   {'id': 'OVAV0k2O1kqeuRFyt95qzg',
#    'alias': 'ma-kin-middle-village-3',
#    'name': 'Ma Kin',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/HKS9ClA3DITKpnzWjhFm6w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ma-kin-middle-village-3?adjust_creative=BEubh_gw8oLY50Nph3EDhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BEubh_gw8oLY50Nph3EDhg',
#    'review_count': 92,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7130368, 'longitude': -73.8775219},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '7419 Metropolitan Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Middle Village',
#     'zip_code': '11379',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['7419 Metropolitan Ave', 'Middle Village, NY 11379']},
#    'phone': '+13475071234',
#    'display_phone': '(347) 507-1234',
#    'distance': 2915.288989938397},
#   {'id': 'a-Bq_yXFVk2PptoWpmry3w',
#    'alias': 'pye-boat-noodle-astoria',
#    'name': 'Pye Boat Noodle',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/jxPnZAwHuRciVqUAd14P4Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pye-boat-noodle-astoria?adjust_creative=BEubh_gw8oLY50Nph3EDhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BEubh_gw8oLY50Nph3EDhg',
#    'review_count': 837,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.76043, 'longitude': -73.92152},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '35-13 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'Astoria',
#     'zip_code': '11106',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['35-13 Broadway', 'Astoria, NY 11106']},
#    'phone': '+17186852329',
#    'display_phone': '(718) 685-2329',
#    'distance': 6625.086426070104},
#   {'id': 'oNN202L_XcNM-tuDHlgkfg',
#    'alias': 'boon-chu-thai-place-elmhurst',
#    'name': 'Boon Chu Thai Place',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/0ffVw7NKAcTDUIPfd5tUwA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/boon-chu-thai-place-elmhurst?adjust_creative=BEubh_gw8oLY50Nph3EDhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BEubh_gw8oLY50Nph3EDhg',
#    'review_count': 313,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.740638, 'longitude': -73.879645},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '83-18 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'Elmhurst',
#     'zip_code': '11373',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['83-18 Broadway', 'Elmhurst, NY 11373']},
#    'phone': '+17188986836',
#    'display_phone': '(718) 898-6836',
#    'distance': 2477.7303260455205},
#   {'id': 'STx4mlpKJVrjd6eZu4yDIw',
#    'alias': 'heng-thai-long-island-city',
#    'name': 'Heng Thai',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/TNglrhhC7IGOBrdkTu-h-g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/heng-thai-long-island-city?adjust_creative=BEubh_gw8oLY50Nph3EDhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BEubh_gw8oLY50Nph3EDhg',
#    'review_count': 10,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.74491469312005,
#     'longitude': -73.94774386999885},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '23-06 Jackson Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Long Island City',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['23-06 Jackson Ave', 'Long Island City, NY 11101']},
#    'phone': '+17187060999',
#    'display_phone': '(718) 706-0999',
#    'distance': 8134.151172667756},
#   {'id': '5pzc2GdvdmqiLRSdjHnnKw',
#    'alias': 'bangkok-avenue-little-neck-2',
#    'name': 'Bangkok Avenue',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/-6MNVU7V930qB3PvdLHKAw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bangkok-avenue-little-neck-2?adjust_creative=BEubh_gw8oLY50Nph3EDhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BEubh_gw8oLY50Nph3EDhg',
#    'review_count': 86,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.77135, 'longitude': -73.73529},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '253-21 Northern Blvd',
#     'address2': None,
#     'address3': '',
#     'city': 'Little Neck',
#     'zip_code': '11362',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['253-21 Northern Blvd', 'Little Neck, NY 11362']},
#    'phone': '+19143033388',
#    'display_phone': '(914) 303-3388',
#    'distance': 10849.613791106447},
#   {'id': '1svF14BUYt_Wc0XA3nMxdw',
#    'alias': 'cha-lom-thai-flushing',
#    'name': 'Cha Lom Thai',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/LUcuIr0hXhAy8DMUMbClFA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cha-lom-thai-flushing?adjust_creative=BEubh_gw8oLY50Nph3EDhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BEubh_gw8oLY50Nph3EDhg',
#    'review_count': 59,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7663429058334,
#     'longitude': -73.7893586550144},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '33-47 Francis Lewis Blvd',
#     'address2': None,
#     'address3': '',
#     'city': 'Flushing',
#     'zip_code': '11358',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['33-47 Francis Lewis Blvd', 'Flushing, NY 11358']},
#    'phone': '+17182696821',
#    'display_phone': '(718) 269-6821',
#    'distance': 6606.083966623151},
#   {'id': 'PPQSf_1JWkbjFHi1S0nSNA',
#    'alias': 'lamoon-elmhurst',
#    'name': 'Lamoon',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/YNrzpdKbmrGLFOtPUwFW6Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lamoon-elmhurst?adjust_creative=BEubh_gw8oLY50Nph3EDhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BEubh_gw8oLY50Nph3EDhg',
#    'review_count': 268,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.742890245749, 'longitude': -73.883034010715},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '8140 Broadway',
#     'address2': '',
#     'address3': None,
#     'city': 'Elmhurst',
#     'zip_code': '11373',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['8140 Broadway', 'Elmhurst, NY 11373']},
#    'phone': '+19177451168',
#    'display_phone': '(917) 745-1168',
#    'distance': 2843.1620995374224},
#   {'id': 'Ve_iFpnhL8zN789ZL2jnxQ',
#    'alias': 'uthai-rego-park',
#    'name': 'UThai',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/EyX6yAydMLYFXZc7dY7PRQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/uthai-rego-park?adjust_creative=BEubh_gw8oLY50Nph3EDhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BEubh_gw8oLY50Nph3EDhg',
#    'review_count': 219,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'vegan', 'title': 'Vegan'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7282415, 'longitude': -73.8639467},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '63-55 Wetherole St',
#     'address2': None,
#     'address3': '',
#     'city': 'Rego Park',
#     'zip_code': '11374',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['63-55 Wetherole St', 'Rego Park, NY 11374']},
#    'phone': '+17188971575',
#    'display_phone': '(718) 897-1575',
#    'distance': 1001.8808045720075},
#   {'id': 'tVB11pOiDhPWlt_o6ylMNg',
#    'alias': 'enthaice-thai-kitchen-astoria',
#    'name': 'Enthaice Thai Kitchen',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/poiYY93PvnCGFXQAEvO-Ng/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/enthaice-thai-kitchen-astoria?adjust_creative=BEubh_gw8oLY50Nph3EDhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BEubh_gw8oLY50Nph3EDhg',
#    'review_count': 695,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'chicken_wings', 'title': 'Chicken Wings'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7630889337809,
#     'longitude': -73.9213237166405},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '33-20 31st Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Astoria',
#     'zip_code': '11106',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['33-20 31st Ave', 'Astoria, NY 11106']},
#    'phone': '+17189321111',
#    'display_phone': '(718) 932-1111',
#    'distance': 6755.95967403878},
#   {'id': 'inftQdKaEEiqQ323AlomXg',
#    'alias': 'dek-sen-elmhurst-2',
#    'name': 'Dek Sen',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/VV_1YWKJXD_BEvAfQ2-wGw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dek-sen-elmhurst-2?adjust_creative=BEubh_gw8oLY50Nph3EDhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BEubh_gw8oLY50Nph3EDhg',
#    'review_count': 278,
#    'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.741714, 'longitude': -73.878689},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '8608 Whitney Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Elmhurst',
#     'zip_code': '11373',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['8608 Whitney Ave', 'Elmhurst, NY 11373']},
#    'phone': '+17182055181',
#    'display_phone': '(718) 205-5181',
#    'distance': 2452.1963359930987},
#   {'id': 'a23bfZBVjIhV32Em4hKHAA',
#    'alias': 'the-buffs-long-island-city-4',
#    'name': 'The Buffs',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/lQID-gz3kJ6Gw-Yr8rLVKQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-buffs-long-island-city-4?adjust_creative=BEubh_gw8oLY50Nph3EDhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BEubh_gw8oLY50Nph3EDhg',
#    'review_count': 106,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7556342, 'longitude': -73.9417121},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1313 40th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Long Island City',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1313 40th Ave', 'Long Island City, NY 11101']},
#    'phone': '+17183612362',
#    'display_phone': '(718) 361-2362',
#    'distance': 7918.772733558018},
#   {'id': 'CpY77cDN1KS5EdiXMmWovw',
#    'alias': 'house-of-thai-long-island-city-4',
#    'name': 'House of Thai',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/uZJDECEq7QBfrSIfyrPsRQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/house-of-thai-long-island-city-4?adjust_creative=BEubh_gw8oLY50Nph3EDhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BEubh_gw8oLY50Nph3EDhg',
#    'review_count': 301,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7535257695712,
#     'longitude': -73.9377629319284},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '2501 40th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Long Island City',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2501 40th Ave', 'Long Island City, NY 11101']},
#    'phone': '+19295220247',
#    'display_phone': '(929) 522-0247',
#    'distance': 7562.962070152043},
#   {'id': 'PyaeHq_UAu6nazGiy0XAnw',
#    'alias': 'ginger-and-lemongrass-whitestone',
#    'name': 'Ginger and Lemongrass',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/rc7pZR40ZmAVzeenf48eZA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ginger-and-lemongrass-whitestone?adjust_creative=BEubh_gw8oLY50Nph3EDhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BEubh_gw8oLY50Nph3EDhg',
#    'review_count': 801,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#     {'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7892691, 'longitude': -73.813717},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1253 150th St',
#     'address2': None,
#     'address3': '',
#     'city': 'Whitestone',
#     'zip_code': '11357',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1253 150th St', 'Whitestone, NY 11357']},
#    'phone': '+13477324720',
#    'display_phone': '(347) 732-4720',
#    'distance': 7222.985916370918},
#   {'id': 'yCJHIM-PWl54K53ACOpoNg',
#    'alias': 'hug-esan-elmhurst',
#    'name': 'Hug Esan',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/6solnO-f4-uAP7irlf1MZA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hug-esan-elmhurst?adjust_creative=BEubh_gw8oLY50Nph3EDhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BEubh_gw8oLY50Nph3EDhg',
#    'review_count': 169,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7436465, 'longitude': -73.8873753},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '77-16 Woodside Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Elmhurst',
#     'zip_code': '11373',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['77-16 Woodside Ave', 'Elmhurst, NY 11373']},
#    'phone': '+19293280392',
#    'display_phone': '(929) 328-0392',
#    'distance': 3209.1609507515063},
#   {'id': 'm2_ZNFos5ugAwe8ft8eaEw',
#    'alias': 'eim-khao-mun-kai-elmhurst-elmhurst',
#    'name': 'Eim Khao Mun Kai Elmhurst',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/JqeuGqrZxCPGVowAEs8XFQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/eim-khao-mun-kai-elmhurst-elmhurst?adjust_creative=BEubh_gw8oLY50Nph3EDhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BEubh_gw8oLY50Nph3EDhg',
#    'review_count': 457,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'hainan', 'title': 'Hainan'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7429414097644,
#     'longitude': -73.8832733356575},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '81-32 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'Elmhurst',
#     'zip_code': '11373',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['81-32 Broadway', 'Elmhurst, NY 11373']},
#    'phone': '+17184247156',
#    'display_phone': '(718) 424-7156',
#    'distance': 2863.74521041377},
#   {'id': 'kXuubLd6s3GidpqU3psPdw',
#    'alias': 'chao-thai-elmhurst-3',
#    'name': 'Chao Thai',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Sq1y11AFR9zp81X0aH9vKw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chao-thai-elmhurst-3?adjust_creative=BEubh_gw8oLY50Nph3EDhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BEubh_gw8oLY50Nph3EDhg',
#    'review_count': 379,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7414656, 'longitude': -73.8801273},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '8503 Whitney Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Elmhurst',
#     'zip_code': '11373',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['8503 Whitney Ave', 'Elmhurst, NY 11373']},
#    'phone': '+17184244999',
#    'display_phone': '(718) 424-4999',
#    'distance': 2568.855535856452},
#   {'id': 'hA5QUlrSjpxMZ90Kof0bgA',
#    'alias': 'khao-kang-elmhurst',
#    'name': 'Khao Kang',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/vfRK27R36XLI4wHpZr6bHQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/khao-kang-elmhurst?adjust_creative=BEubh_gw8oLY50Nph3EDhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BEubh_gw8oLY50Nph3EDhg',
#    'review_count': 244,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.743269, 'longitude': -73.888039},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '7620 Woodside Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Elmhurst',
#     'zip_code': '11373',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['7620 Woodside Ave', 'Elmhurst, NY 11373']},
#    'phone': '+17188061807',
#    'display_phone': '(718) 806-1807',
#    'distance': 3242.7336966969283},
#   {'id': 'a5H9p1B6m6WPVjakPylvdA',
#    'alias': 'spicy-shallot-elmhurst',
#    'name': 'Spicy Shallot',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/OzUSMfiNLzDNthJuYxni0Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/spicy-shallot-elmhurst?adjust_creative=BEubh_gw8oLY50Nph3EDhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BEubh_gw8oLY50Nph3EDhg',
#    'review_count': 633,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7437053273707,
#     'longitude': -73.8878916857991},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '7701 Woodside Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Elmhurst',
#     'zip_code': '11373',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['7701 Woodside Ave', 'Elmhurst, NY 11373']},
#    'phone': '+17186725266',
#    'display_phone': '(718) 672-5266',
#    'distance': 3251.3867012082496},
#   {'id': 'rehmlZmUNL2AthW-VTXJJQ',
#    'alias': 'tasty-thai-ridgewood',
#    'name': 'Tasty Thai',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/NX0ocs11fl3Dj1kTmpBrRw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tasty-thai-ridgewood?adjust_creative=BEubh_gw8oLY50Nph3EDhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BEubh_gw8oLY50Nph3EDhg',
#    'review_count': 86,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.69984, 'longitude': -73.89958},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '72-04 Forest Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Ridgewood',
#     'zip_code': '11385',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['72-04 Forest Ave', 'Ridgewood, NY 11385']},
#    'phone': '+19179090937',
#    'display_phone': '(917) 909-0937',
#    'distance': 5281.3840549926945},
#   {'id': 'zRQNaDUoWTInc2tqndSJVA',
#    'alias': 'thai-101-bayside',
#    'name': 'Thai 101',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/dvejY_8barqkhtUQt35Hkw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/thai-101-bayside?adjust_creative=BEubh_gw8oLY50Nph3EDhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BEubh_gw8oLY50Nph3EDhg',
#    'review_count': 306,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.76488, 'longitude': -73.77133},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '39-15 Bell Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Bayside',
#     'zip_code': '11361',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['39-15 Bell Blvd', 'Bayside, NY 11361']},
#    'phone': '+17186318600',
#    'display_phone': '(718) 631-8600',
#    'distance': 7803.89291133938},
#   {'id': 'YMcDo3UccCPvIJrQ5Yt9Yw',
#    'alias': 'chám-thai-cuisine-ridgewood',
#    'name': 'Chám Thai Cuisine',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/_INscq_GSjWwiY03XfcQbA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ch%C3%A1m-thai-cuisine-ridgewood?adjust_creative=BEubh_gw8oLY50Nph3EDhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BEubh_gw8oLY50Nph3EDhg',
#    'review_count': 48,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7025939, 'longitude': -73.901464},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '881 Woodward Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Ridgewood',
#     'zip_code': '11385',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['881 Woodward Ave', 'Ridgewood, NY 11385']},
#    'phone': '+17188944404',
#    'display_phone': '(718) 894-4404',
#    'distance': 5205.517479140647},
#   {'id': 'wEawMdWT7UtZjEmmMTBiGA',
#    'alias': 'saranrom-thai-elmhurst-2',
#    'name': 'Saranrom Thai',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/kfH2mX_qFCnGegh9CUY_rg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/saranrom-thai-elmhurst-2?adjust_creative=BEubh_gw8oLY50Nph3EDhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BEubh_gw8oLY50Nph3EDhg',
#    'review_count': 32,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7431528, 'longitude': -73.8836694},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '8110 Broadway',
#     'address2': None,
#     'address3': '',
#     'city': 'Elmhurst',
#     'zip_code': '11373',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['8110 Broadway', 'Elmhurst, NY 11373']},
#    'phone': '+19178326672',
#    'display_phone': '(917) 832-6672',
#    'distance': 2905.2906392679156},
#   {'id': 'OR9oqAJW-U5ZnqhwH12Nuw',
#    'alias': 'khao-nom-elmhurst',
#    'name': 'Khao Nom',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/fiPmRRzFIz4WRhuyAyGXXQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/khao-nom-elmhurst?adjust_creative=BEubh_gw8oLY50Nph3EDhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BEubh_gw8oLY50Nph3EDhg',
#    'review_count': 116,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7432731562959,
#     'longitude': -73.8879961885031},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '42-06 77th St',
#     'address2': '',
#     'address3': None,
#     'city': 'Elmhurst',
#     'zip_code': '11373',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['42-06 77th St', 'Elmhurst, NY 11373']},
#    'phone': '+19292080108',
#    'display_phone': '(929) 208-0108',
#    'distance': 3250.841753204315},
#   {'id': 'toykv8K0yg8qtvZSXRQ5bg',
#    'alias': 'pochana-thai-kitchen-astoria-2',
#    'name': 'Pochana Thai Kitchen',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/5hfYhHZOsD9SRICjUaFpYQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pochana-thai-kitchen-astoria-2?adjust_creative=BEubh_gw8oLY50Nph3EDhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BEubh_gw8oLY50Nph3EDhg',
#    'review_count': 193,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.765733, 'longitude': -73.91932},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '33-16 30th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Astoria',
#     'zip_code': '11103',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['33-16 30th Ave', 'Astoria, NY 11103']},
#    'phone': '+17189569559',
#    'display_phone': '(718) 956-9559',
#    'distance': 6773.2440684776475},
#   {'id': 'dnCRiUZWgu5ZI4Q-Z-az6Q',
#    'alias': 'thai-diva-cuisine-woodside-3',
#    'name': 'Thai Diva Cuisine',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/FAxltkvgVnPp87i9Uq90Ew/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/thai-diva-cuisine-woodside-3?adjust_creative=BEubh_gw8oLY50Nph3EDhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BEubh_gw8oLY50Nph3EDhg',
#    'review_count': 140,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'soup', 'title': 'Soup'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7414512, 'longitude': -73.9190131},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '45-53 46th St',
#     'address2': None,
#     'address3': '',
#     'city': 'Woodside',
#     'zip_code': '11377',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['45-53 46th St', 'Woodside, NY 11377']},
#    'phone': '+19292080282',
#    'display_phone': '(929) 208-0282',
#    'distance': 5684.506606279269},
#   {'id': 'ipxeCjihDqXTMkuPe-CQ4A',
#    'alias': 'arunee-thai-jackson-heights',
#    'name': 'Arunee Thai',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/yBzXFJre13F2BtJNRiWAlA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/arunee-thai-jackson-heights?adjust_creative=BEubh_gw8oLY50Nph3EDhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BEubh_gw8oLY50Nph3EDhg',
#    'review_count': 317,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7494503, 'longitude': -73.8873621},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '78-23 37th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Jackson Heights',
#     'zip_code': '11372',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['78-23 37th Ave', 'Jackson Heights, NY 11372']},
#    'phone': '+17182055559',
#    'display_phone': '(718) 205-5559',
#    'distance': 3529.3232402943213},
#   {'id': '8-dc942sz-prIeepAkHLJA',
#    'alias': 'zenith-thai-restaurant-ridgewood',
#    'name': 'Zenith Thai Restaurant',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/P5WjD6_4bZyV6AVgkeceaw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/zenith-thai-restaurant-ridgewood?adjust_creative=BEubh_gw8oLY50Nph3EDhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BEubh_gw8oLY50Nph3EDhg',
#    'review_count': 113,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7023726, 'longitude': -73.8952926},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '7002 Fresh Pond Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Ridgewood',
#     'zip_code': '11385',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['7002 Fresh Pond Rd', 'Ridgewood, NY 11385']},
#    'phone': '+17184978899',
#    'display_phone': '(718) 497-8899',
#    'distance': 4825.743443483346},
#   {'id': 'Eyn7hQENF8R9DrBwBHO6lQ',
#    'alias': 'pata-cafe-elmhurst',
#    'name': 'Pata Cafe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/XaAZQtUInh_RNGATh7ImpA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pata-cafe-elmhurst?adjust_creative=BEubh_gw8oLY50Nph3EDhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BEubh_gw8oLY50Nph3EDhg',
#    'review_count': 73,
#    'categories': [{'alias': 'bubbletea', 'title': 'Bubble Tea'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7326341, 'longitude': -73.8769762},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '5614 Van Horn St',
#     'address2': None,
#     'address3': '',
#     'city': 'Elmhurst',
#     'zip_code': '11373',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['5614 Van Horn St', 'Elmhurst, NY 11373']},
#    'phone': '+13474697142',
#    'display_phone': '(347) 469-7142',
#    'distance': 2013.709004982964},
#   {'id': '1wdJ1vJR_Z1vJebQGlZU3Q',
#    'alias': 'krung-tep-thai-bistro-great-neck-plaza',
#    'name': 'Krung Tep Thai Bistro',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Nwo0m4I7O95U2Kp9-JRoIQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/krung-tep-thai-bistro-great-neck-plaza?adjust_creative=BEubh_gw8oLY50Nph3EDhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BEubh_gw8oLY50Nph3EDhg',
#    'review_count': 223,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.78661, 'longitude': -73.725858},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '23 S Middle Neck Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Great Neck Plaza',
#     'zip_code': '11021',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['23 S Middle Neck Rd', 'Great Neck Plaza, NY 11021']},
#    'phone': '+15164989889',
#    'display_phone': '(516) 498-9889',
#    'distance': 12337.29866702809},
#   {'id': '2ZBEE_MJeRdLD1NLiNTnCQ',
#    'alias': 'thailands-center-point-woodside-2',
#    'name': "Thailand's Center Point",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/o99eLojQrJOaEe1keKZEug/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/thailands-center-point-woodside-2?adjust_creative=BEubh_gw8oLY50Nph3EDhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BEubh_gw8oLY50Nph3EDhg',
#    'review_count': 196,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.746738, 'longitude': -73.900162},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '63-19 39th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Woodside',
#     'zip_code': '11377',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['63-19 39th Ave', 'Woodside, NY 11377']},
#    'phone': '+17186516888',
#    'display_phone': '(718) 651-6888',
#    'distance': 4333.1887147697735},
#   {'id': 'ET4xGd-SQ6gs9lce4xVpQg',
#    'alias': 'tum-thai-cuisine-rockville-centre',
#    'name': 'Tum Thai Cuisine',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/0keHJi1yLq97gnDyCeM7UQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tum-thai-cuisine-rockville-centre?adjust_creative=BEubh_gw8oLY50Nph3EDhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BEubh_gw8oLY50Nph3EDhg',
#    'review_count': 641,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.65591, 'longitude': -73.64574},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '274 Merrick Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Rockville Centre',
#     'zip_code': '11570',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['274 Merrick Rd', 'Rockville Centre, NY 11570']},
#    'phone': '+15165435078',
#    'display_phone': '(516) 543-5078',
#    'distance': 19384.513491944435},
#   {'id': 'nu239sXQUGjcGFhZ3AdJmQ',
#    'alias': 'erawan-thai-cuisine-bayside',
#    'name': 'Erawan Thai Cuisine',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/x_vmcrpshZxNmtw9sKHzwA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/erawan-thai-cuisine-bayside?adjust_creative=BEubh_gw8oLY50Nph3EDhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BEubh_gw8oLY50Nph3EDhg',
#    'review_count': 346,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.761821, 'longitude': -73.769775},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '4231 Bell Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Bayside',
#     'zip_code': '11361',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['4231 Bell Blvd', 'Bayside, NY 11361']},
#    'phone': '+17184282112',
#    'display_phone': '(718) 428-2112',
#    'distance': 7766.294526950914},
#   {'id': '2pJ782hnKTK0MWbc0H7EDw',
#    'alias': 'ditmars-thai-astoria',
#    'name': 'Ditmars Thai',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/P4ei6AZRi77oR6HcHLJMbg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ditmars-thai-astoria?adjust_creative=BEubh_gw8oLY50Nph3EDhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BEubh_gw8oLY50Nph3EDhg',
#    'review_count': 12,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.77473, 'longitude': -73.90825},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '35-13 Ditmars Blvd',
#     'address2': '',
#     'address3': None,
#     'city': 'Astoria',
#     'zip_code': '11105',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['35-13 Ditmars Blvd', 'Astoria, NY 11105']},
#    'phone': '+17182694549',
#    'display_phone': '(718) 269-4549',
#    'distance': 6703.073797984971},
#   {'id': 'QWskQ2QpR8bmza2FRFziOQ',
#    'alias': 'asian-fortune-restaurant-forest-hills',
#    'name': 'Asian Fortune Restaurant',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Av0ZXxYsKSXnZ8z182gh0g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/asian-fortune-restaurant-forest-hills?adjust_creative=BEubh_gw8oLY50Nph3EDhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BEubh_gw8oLY50Nph3EDhg',
#    'review_count': 114,
#    'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'},
#     {'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7244621, 'longitude': -73.8493213},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '103-35 Queens Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Forest Hills',
#     'zip_code': '11375',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['103-35 Queens Blvd', 'Forest Hills, NY 11375']},
#    'phone': '+17188306313',
#    'display_phone': '(718) 830-6313',
#    'distance': 851.8262088216507},
#   {'id': 'khvnn7cpiYSpe80ue5YLvg',
#    'alias': 'ddee-thai-astoria',
#    'name': 'Ddee Thai',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/mVpYungatdQ1AFuujOjTdA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ddee-thai-astoria?adjust_creative=BEubh_gw8oLY50Nph3EDhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BEubh_gw8oLY50Nph3EDhg',
#    'review_count': 37,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.762909, 'longitude': -73.91325},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '42-06 30th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Astoria',
#     'zip_code': '11103',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['42-06 30th Ave', 'Astoria, NY 11103']},
#    'phone': '+17186261222',
#    'display_phone': '(718) 626-1222',
#    'distance': 6173.635697332506},
#   {'id': 'MxMWPaC30sRkPKit_Omz2A',
#    'alias': 'khun-noo-thai-noodle-house-woodside',
#    'name': 'Khun Noo Thai Noodle House',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/85O4rR5ovWEeOa7sy1El2Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/khun-noo-thai-noodle-house-woodside?adjust_creative=BEubh_gw8oLY50Nph3EDhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BEubh_gw8oLY50Nph3EDhg',
#    'review_count': 51,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.74568, 'longitude': -73.91261},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '51-20 Skillman Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Woodside',
#     'zip_code': '11377',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['51-20 Skillman Ave', 'Woodside, NY 11377']},
#    'phone': '+17184268162',
#    'display_phone': '(718) 426-8162',
#    'distance': 5278.326423160265},
#   {'id': 'YIgBb6jb_KV0-nbYZ1oPig',
#    'alias': 'barn-na-thai-ridgewood',
#    'name': 'BARN NA THAI',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/GAI2zkiVLyalqT0cX3K3vg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/barn-na-thai-ridgewood?adjust_creative=BEubh_gw8oLY50Nph3EDhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BEubh_gw8oLY50Nph3EDhg',
#    'review_count': 16,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.71012, 'longitude': -73.89958},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '6402 Fresh Pond Rd',
#     'address2': None,
#     'address3': None,
#     'city': 'RIDGEWOOD',
#     'zip_code': '11385',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['6402 Fresh Pond Rd', 'RIDGEWOOD, NY 11385']},
#    'phone': '+19293878065',
#    'display_phone': '(929) 387-8065',
#    'distance': 4594.843164144977},
#   {'id': 'SkYcO8FaqYgoP-66g58OMw',
#    'alias': 'thai-pot-forest-hills',
#    'name': 'Thai Pot',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Qu_oE3bTpWt-pJw8r4LXxw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/thai-pot-forest-hills?adjust_creative=BEubh_gw8oLY50Nph3EDhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BEubh_gw8oLY50Nph3EDhg',
#    'review_count': 246,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.7247545048924,
#     'longitude': -73.8498401641846},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '103-07 Queens Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Forest Hills',
#     'zip_code': '11375',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['103-07 Queens Blvd', 'Forest Hills, NY 11375']},
#    'phone': '+17188973898',
#    'display_phone': '(718) 897-3898',
#    'distance': 788.0501952017784},
#   {'id': 'qrydcGQpeDP_1oFvx3qOeg',
#    'alias': 'somtum-der-new-york',
#    'name': 'Somtum Der',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/85AftnoxLOq0T0HKHPSdgg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/somtum-der-new-york?adjust_creative=BEubh_gw8oLY50Nph3EDhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BEubh_gw8oLY50Nph3EDhg',
#    'review_count': 753,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7252151982238,
#     'longitude': -73.9842741682317},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '85 Ave A',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['85 Ave A', 'New York, NY 10009']},
#    'phone': '+12122608570',
#    'display_phone': '(212) 260-8570',
#    'distance': 11096.694980469541},
#   {'id': 'zENn0_yDJEdLoHyivXb2xw',
#    'alias': 'black-thai-jackson-heights-4',
#    'name': 'Black Thai',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/kxJrShs7FqI0OaNE1d01aw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/black-thai-jackson-heights-4?adjust_creative=BEubh_gw8oLY50Nph3EDhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BEubh_gw8oLY50Nph3EDhg',
#    'review_count': 290,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7553269, 'longitude': -73.8860092},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '81-16 Northern Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Jackson Heights',
#     'zip_code': '11372',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['81-16 Northern Blvd', 'Jackson Heights, NY 11372']},
#    'phone': '+17187798424',
#    'display_phone': '(718) 779-8424',
#    'distance': 3827.0847177331707}],
#  'total': 2600,
#  'region': {'center': {'longitude': -73.85284423828125,
#    'latitude': 40.73146603137887}}}

# %% [markdown]
# Using one of the methods above load the response data and assign it to a variable `data`.

# %%
data = response.json()

# %%
type(data)
# Out:
# dict

# %% [markdown]
# What are the keys in this dictionary and the datatypes of their values.

# %%
# your code here
data.keys()
# Out:
# dict_keys(['businesses', 'total', 'region'])

# %% [markdown]
# > Look at the 'https://api.yelp.com/v3/businesses/search' for the parameters for the dict keys above!

# %% [markdown]
# How many results did our query return?

# %%
data['total']
# Out:
# 2600

# %% [markdown]
# How many businesses were returned from the API call?

# %%
len(data['businesses'])
# Out:
# 50

# %% [markdown]
# > The cell below is a function that makes a yelp call and returns it in a JSON readable form

# %%
def yelp_call(url_params):
    response = requests.get(url, headers=headers, params=url_params)
    return response.json()

# %% [markdown]
# ### Parsing the Results
#
# There are a lot of key-value pairs for each business. Many of which we do not care about. Let's create a simple parser of this data that will return a list with the name, display_address, and one other data point of your choice. First we want to assign one of the businesses to the `business` variable. Once we cna properly parse oonne business  we can use a loop to do them all.

# %%
business = data['businesses'][0]

# %%
business
# Out:
# {'id': 'uazg6WhYVOw3jhWCG_MDBg',
#  'alias': 'sup-thai-kitchen-fresh-meadows',
#  'name': 'Sup Thai Kitchen',
#  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ouTt4JK93LOG0P7fSG1r7g/o.jpg',
#  'is_closed': False,
#  'url': 'https://www.yelp.com/biz/sup-thai-kitchen-fresh-meadows?adjust_creative=BEubh_gw8oLY50Nph3EDhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BEubh_gw8oLY50Nph3EDhg',
#  'review_count': 373,
#  'categories': [{'alias': 'thai', 'title': 'Thai'},
#   {'alias': 'seafood', 'title': 'Seafood'},
#   {'alias': 'noodles', 'title': 'Noodles'}],
#  'rating': 4.5,
#  'coordinates': {'latitude': 40.7266838, 'longitude': -73.7894371},
#  'transactions': ['delivery', 'pickup'],
#  'price': '$$',
#  'location': {'address1': '178-19 Union Tpke',
#   'address2': None,
#   'address3': '',
#   'city': 'Fresh Meadows',
#   'zip_code': '11366',
#   'country': 'US',
#   'state': 'NY',
#   'display_address': ['178-19 Union Tpke', 'Fresh Meadows, NY 11366']},
#  'phone': '+17184874449',
#  'display_phone': '(718) 487-4449',
#  'distance': 5378.159709707153}

# %% [markdown]
# Rember we want the following pieces of information:
# name, display_address, and one other data point of your choice

# %%
biz_tuple = (business['name'], business['location']['zip_code'], business['rating'])

# %%
biz_tuple
# Out:
# ('Sup Thai Kitchen', '11366', 4.5)

# %% [markdown]
# Now that we know how to do this for one business. Let create a function that recieves the list of businesses and returns a list of tuples with the important information.

# %%
def parse_data(list_of_data):
    # create a container to hold our parsed data
    businesses = []
    # loop through our business and 
    for business in list_of_data:
    # parse each individual business into a tuple
        biz_tuple = (business['name'], business['location']['zip_code'], business['rating'] )
    # add each individual business tuple to our data container
        businesses.append(biz_tuple)
    # return the container with all of the parsed results
     
    return businesses

# %% [markdown]
# > This is a shortcut way:
# businesses =
# list(map(lambda business: (business['name'], business['location']['zip_code'], business['rating']), list_of_data))

# %%
parse_data(data['businesses'])
# Out:
# [('Sup Thai Kitchen', '11366', 4.5),
#  ("Kin'd", '11366', 4.5),
#  ('SriPraPhai Thai Restaurant', '11377', 4.0),
#  ('Bangkok Cuisine', '11375', 4.0),
#  ('Grace Thai Restaurant', '11373', 4.5),
#  ('Kitchen 79', '11372', 4.5),
#  ('Ayada Thai', '11373', 4.0),
#  ('BKNY Thai Restaurant', '11361', 4.0),
#  ('Thai Mission', '11378', 5.0),
#  ('Nur Thai', '11374', 4.0),
#  ('Ma Kin', '11379', 4.5),
#  ('Pye Boat Noodle', '11106', 4.5),
#  ('Boon Chu Thai Place', '11373', 4.0),
#  ('Heng Thai', '11101', 5.0),
#  ('Bangkok Avenue', '11362', 5.0),
#  ('Cha Lom Thai', '11358', 4.5),
#  ('Lamoon', '11373', 4.5),
#  ('UThai', '11374', 4.0),
#  ('Enthaice Thai Kitchen', '11106', 4.0),
#  ('Dek Sen', '11373', 4.0),
#  ('The Buffs', '11101', 4.5),
#  ('House of Thai', '11101', 4.0),
#  ('Ginger and Lemongrass', '11357', 4.0),
#  ('Hug Esan', '11373', 4.5),
#  ('Eim Khao Mun Kai Elmhurst', '11373', 4.5),
#  ('Chao Thai', '11373', 4.0),
#  ('Khao Kang', '11373', 4.0),
#  ('Spicy Shallot', '11373', 4.0),
#  ('Tasty Thai', '11385', 4.0),
#  ('Thai 101', '11361', 3.5),
#  ('Chám Thai Cuisine', '11385', 3.5),
#  ('Saranrom Thai', '11373', 4.5),
#  ('Khao Nom', '11373', 4.5),
#  ('Pochana Thai Kitchen', '11103', 4.0),
#  ('Thai Diva Cuisine', '11377', 4.0),
#  ('Arunee Thai', '11372', 4.0),
#  ('Zenith Thai Restaurant', '11385', 4.0),
#  ('Pata Cafe', '11373', 4.5),
#  ('Krung Tep Thai Bistro', '11021', 4.0),
#  ("Thailand's Center Point", '11377', 4.0),
#  ('Tum Thai Cuisine', '11570', 4.5),
#  ('Erawan Thai Cuisine', '11361', 3.5),
#  ('Ditmars Thai', '11105', 5.0),
#  ('Asian Fortune Restaurant', '11375', 4.0),
#  ('Ddee Thai', '11103', 4.5),
#  ('Khun Noo Thai Noodle House', '11377', 4.5),
#  ('BARN NA THAI', '11385', 4.5),
#  ('Thai Pot', '11375', 3.0),
#  ('Somtum Der', '10009', 4.0),
#  ('Black Thai', '11372', 4.0)]

# %%
parsed_results = parse_data(data['businesses'])

# %% [markdown]
# Take the parsed results and put them in a Dataframe.

# %%
import pandas as pd

# %%
df = pd.DataFrame(parsed_results, columns=['Name', 'Zipcode', 'Rating'])
df.head()
# Out:
#                          Name Zipcode  Rating
# 0            Sup Thai Kitchen   11366     4.5
# 1                       Kin'd   11366     4.5
# 2  SriPraPhai Thai Restaurant   11377     4.0
# 3             Bangkok Cuisine   11375     4.0
# 4       Grace Thai Restaurant   11373     4.5
