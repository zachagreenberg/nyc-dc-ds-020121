# %%
import functions

# %%
functions.most_popular_artist()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-9bd211dea234> in <module>
# ----> 1 functions.most_popular_artist()
#
# TypeError: most_popular_artist() missing 1 required positional argument: 'our_data'

# %%
import
